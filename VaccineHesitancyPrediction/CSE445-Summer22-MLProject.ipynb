# %%
##!wget -q https://data.mendeley.com/public-files/datasets/j78w4s258j/files/b387e359-15f6-4cfc-847a-ba82167e6f65/file_downloaded -O 'Vaccine Hesitancy.csv'

import pandas as pd
import numpy as np
import pickle

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import dataset
data = pd.read_csv('Vaccine Hesitancy.csv', encoding='cp1252')

# %% [markdown]
# EDA

# %%
data.shape  # number of rows & columns
# Out:
# (413, 41)

# %%
data.info()  # see columns in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 41 columns):
#  #   Column                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                         --------------  -----
#  0   County                                                                                                                                         413 non-null    object
#  1   District                                                                                                                                       413 non-null    object
#  2   Sex                                                                                                                                            413 non-null    object
#  3   Age                                                                                                                                            413 non-null    object
#  4   Religion                                                                                                                                       413 non-null    object
#  5   Education                                                                                                                                      413 non-null    object
#  6   Years                                                                                                                                          413 non-null    object
#  7   Households                                                                                                                                     413 non-null    object
#  8   Have you had MoH approved training on COVID-19?                                                                                                413 non-null    object
#  9   Have you been involved in educating the community on COVID-19?                                                                                 413 non-null    object
#  10  Your main source of Income                                                                                                                     413 non-null    object
#  11  Have you attended a course where COVID-19 vaccination was discussed?                                                                           413 non-null    object
#  12  Do you have access to COVID-19 vaccination materials (literature, IEC materials) for quick reference when necessary?                           413 non-null    object
#  13  Do you have a designated person with knowledge on COVID-19 vaccination whom you can consult when you have a question on COVID-19 vaccination?  413 non-null    object
#  14  Concerning how the COVID-19 vaccines work to prevent infection                                                                                 413 non-null    object
#  15  To what extent do you think you are well-informed enough about COVID-19 vaccine to sensitize your family/ community members?                   413 non-null    object
#  16  Do you know what the COVID-19 vaccine contains?                                                                                                413 non-null    object
#  17  What should the people who have received the COVID-19 vaccine do?                                                                              413 non-null    object
#  18  The effectiveness of COVID-19 vaccines in preventing infection:                                                                                413 non-null    object
#  19  People who have already suffered COVID-19 infection:                                                                                           413 non-null    object
#  20  ACQ1: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  21  ACQ2: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  22  ACQ3: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  23  ACQ4: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  24  ACQ5: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  25  ACQ6: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  26  ACQ7: Attitude on Contextual Influences                                                                                                        413 non-null    object
#  27  AIQ1: Attitude on Individual and Group Influences                                                                                              413 non-null    object
#  28  AIQ12: Attitude on Individual and Group Influences                                                                                             413 non-null    object
#  29  AIQ3: Attitude on Individual and Group Influences                                                                                              413 non-null    object
#  30  AIQ4: Attitude on Individual and Group Influences                                                                                              413 non-null    object
#  31  AIQ5: Attitude on Individual and Group Influences                                                                                              413 non-null    object
#  32  AIQ6: Attitude on Individual and Group Influences                                                                                              413 non-null    object
#  33  AVSQ1: Attitude on Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  34  AVSQ2: Attitudeon  Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  35  AVSQ3: Attitude on Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  36  AVSQ4: Attitude on Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  37  AVSQ5: Attitude on Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  38  AVSQ6: Attitude on Vaccine safety and vaccination specific issues                                                                              413 non-null    object
#  39  Source                                                                                                                                         413 non-null    object
#  40  Information                                                                                                                                    413 non-null    object
# dtypes: object(41)
# memory usage: 132.4+ KB

# %%
data  # look at few data entries
# Out:
#           County       District     Sex             Age    Religion  \
# 0        Nairobi  Embakasi West  Female  Above 35 years    Catholic
# 1        Nairobi      Westlands  Female  Above 35 years  Protestant
# 2        Nairobi      Westlands  Female  Above 35 years      Others
# 3        Nairobi        Langata    Male  Above 35 years       Islam
# 4        Nairobi        Langata  Female     25-35 years    Catholic
# ..           ...            ...     ...             ...         ...
# 408  Trans Nzoia        Sabaoti    Male  Above 35 years  Protestant
# 409  Trans Nzoia         Kwanza  Female  Above 35 years  Protestant
# 410  Trans Nzoia         Kwanza  Female  Above 35 years  Protestant
# 411  Trans Nzoia         Kwanza  Female  Above 35 years  Protestant
# 412  Trans Nzoia        Sabaoti  Female     25-35 years  Protestant
#
#      Education              Years    Households  \
# 0      Primary      Above 5 years  More than 50
# 1      Primary  Less than 3 years         21-50
# 2      Primary      Above 5 years  More than 50
# 3       Others      Above 5 years  More than 50
# 4      Primary      Above 5 years  More than 50
# ..         ...                ...           ...
# 408  Secondary      Above 5 years  More than 50
# 409  Secondary      Above 5 years         21-50
# 410  Secondary      Above 5 years  More than 50
# 411  Secondary      Above 5 years         21-50
# 412    Primary          3-5 years  More than 50
#
#     Have you had MoH approved training on COVID-19?  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
# ..                                              ...
# 408                                             Yes
# 409                                             Yes
# 410                                             Yes
# 411                                             Yes
# 412                                             Yes
#
#     Have you been involved in educating the community on COVID-19?  ...  \
# 0                                                   No              ...
# 1                                                  Yes              ...
# 2                                                  Yes              ...
# 3                                                  Yes              ...
# 4                                                  Yes              ...
# ..                                                 ...              ...
# 408                                                Yes              ...
# 409                                                Yes              ...
# 410                                                Yes              ...
# 411                                                Yes              ...
# 412                                                Yes              ...
#
#     AIQ5: Attitude on Individual and Group Influences  \
# 0                                                  No
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# 408                                               Yes
# 409                                               Yes
# 410                                               Yes
# 411                                               Yes
# 412                                               Yes
#
#     AIQ6: Attitude on Individual and Group Influences  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# 408                                               Yes
# 409                                               Yes
# 410                                               Yes
# 411                                               Yes
# 412                                               Yes
#
#     AVSQ1: Attitude on Vaccine safety and vaccination specific issues  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 408                                                Yes
# 409                                                Yes
# 410                                                Yes
# 411                                                Yes
# 412                                                Yes
#
#     AVSQ2: Attitudeon  Vaccine safety and vaccination specific issues  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                  Yes
# ..                                                 ...
# 408                                                Yes
# 409                                                Yes
# 410                                                Yes
# 411                                                Yes
# 412                                                Yes
#
#     AVSQ3: Attitude on Vaccine safety and vaccination specific issues  \
# 0                                           Don't know
# 1                                       Very confident
# 2                                            Confident
# 3                                       Very confident
# 4                                       Very confident
# ..                                                 ...
# 408                                          Confident
# 409                                  Somehow confident
# 410                                          Confident
# 411                                  Somehow confident
# 412                                          Confident
#
#     AVSQ4: Attitude on Vaccine safety and vaccination specific issues  \
# 0                                           Don't know
# 1                                           Not at all
# 2                                         Not too much
# 3                                         Not too much
# 4                                             Somewhat
# ..                                                 ...
# 408                                           Somewhat
# 409                                           Somewhat
# 410                                         Not at all
# 411                                         Not at all
# 412                                         Not at all
#
#     AVSQ5: Attitude on Vaccine safety and vaccination specific issues  \
# 0    The government might not be able to ensure eno...
# 1                                                  1,8
# 2                                                1,4,5
# 3            Vaccines are not tested enough for safety
# 4    The COVID-19 vaccine might weaken the immunity...
# ..                                                 ...
# 408                                                1,2
# 409  I don’t have any concerns about the COVID-19 v...
# 410  I don’t have any concerns about the COVID-19 v...
# 411  I don’t have any concerns about the COVID-19 v...
# 412  I don’t have any concerns about the COVID-19 v...
#
#     AVSQ6: Attitude on Vaccine safety and vaccination specific issues  \
# 0                                             Somewhat
# 1                                           Not at all
# 2                                         Not too much
# 3                                         Not too much
# 4                                            Very much
# ..                                                 ...
# 408                                           Somewhat
# 409                                          Very much
# 410                                          Very much
# 411                                          Very much
# 412                                          Very much
#
#                              Source            Information
# 0                          Radio/TV               Internet
# 1                          Radio/TV  Fellow health workers
# 2                          Radio/TV  Fellow health workers
# 3                          Radio/TV  Fellow health workers
# 4                          Radio/TV  Fellow health workers
# ..                              ...                    ...
# 408           Social media/Radio/TV  Fellow health workers
# 409                        Radio/TV  Fellow health workers
# 410  Radio/TV/IEC/Community meeting  Fellow health workers
# 411                        Radio/TV  Fellow health workers
# 412                        Radio/TV  Fellow health workers
#
# [413 rows x 41 columns]

# %%
for col in data[data.columns]:
    a = data[col].value_counts()
    print('--------------------------------------')
    print(col)
    print('--------------------------------------')
    print(a)
    print('--------------------------------------\n')
# Out:
# --------------------------------------
# County
# --------------------------------------
# Nairobi        209
# Mombasa         84
# Trans Nzoia     66
# Kajiado         54
# Name: County, dtype: int64
# --------------------------------------
#
# --------------------------------------
# District
# --------------------------------------
# Westlands          55
# Embakasi West      52
# Langata            51
# Kasarani           51
# Kwanza             34
# Sabaoti            32
# Changamwe          28
# Nyali              28
# Kisauni            28
# Kajiado Central    27
# Kajiado East       27
# Name: District, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Sex
# --------------------------------------
# Female    301
# Male      108
# Other       4
# Name: Sex, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Age
# --------------------------------------
# Above 35 years    266
# 25-35 years       116
# 18-24 years        31
# Name: Age, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Religion
# --------------------------------------
# Protestant    233
# Catholic       98
# Others         44
# Islam          38
# Name: Religion, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Education
# --------------------------------------
# Secondary    205
# Primary      116
# Others        89
# None           3
# Name: Education, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Years
# --------------------------------------
# Above 5 years        257
# 3-5 years             85
# Less than 3 years     71
# Name: Years, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Households
# --------------------------------------
# More than 50    309
# 21-50            73
# 20  or less      31
# Name: Households, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Have you had MoH approved training on COVID-19?
# --------------------------------------
# Yes         308
# No           81
# Not sure     24
# Name: Have you had MoH approved training on COVID-19?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Have you been involved in educating the community on COVID-19?
# --------------------------------------
# Yes    356
# No      57
# Name: Have you been involved in educating the community on COVID-19?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Your main source of Income
# --------------------------------------
# Other non-formal employment    211
# CHV work                       178
# Other formal employment         24
# Name: Your main source of Income, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Have you attended a course where COVID-19 vaccination was discussed?
# --------------------------------------
# No     383
# Yes     30
# Name: Have you attended a course where COVID-19 vaccination was discussed?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Do you have access to COVID-19 vaccination materials (literature, IEC materials) for quick reference when necessary?
# --------------------------------------
# No     386
# Yes     27
# Name: Do you have access to COVID-19 vaccination materials (literature, IEC materials) for quick reference when necessary?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Do you have a designated person with knowledge on COVID-19 vaccination whom you can consult when you have a question on COVID-19 vaccination?
# --------------------------------------
# Yes    274
# No     139
# Name: Do you have a designated person with knowledge on COVID-19 vaccination whom you can consult when you have a question on COVID-19 vaccination?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Concerning how the COVID-19 vaccines work to prevent infection
# --------------------------------------
# I do not know how the vaccines work                                                        212
# I have an idea but I am not confident to explain to the community how the vaccines work    155
# I can explain to the community how the vaccines work                                        46
# Name: Concerning how the COVID-19 vaccines work to prevent infection, dtype: int64
# --------------------------------------
#
# --------------------------------------
# To what extent do you think you are well-informed enough about COVID-19 vaccine to sensitize your family/ community members?
# --------------------------------------
# Small extent      178
# Not at all        162
# Average extent     60
# Large extent       13
# Name: To what extent do you think you are well-informed enough about COVID-19 vaccine to sensitize your family/ community members?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Do you know what the COVID-19 vaccine contains?
# --------------------------------------
# No     363
# Yes     50
# Name: Do you know what the COVID-19 vaccine contains?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# What should the people who have received the COVID-19 vaccine do?
# --------------------------------------
# Still have to wear masks, social distance, and wash hands frequently to prevent COVID-19    318
# I do not know                                                                                80
# Do not have to wear masks, social distance or wash hands frequently to prevent COVID-19      15
# Name: What should the people who have received the COVID-19 vaccine do?, dtype: int64
# --------------------------------------
#
# --------------------------------------
# The effectiveness of COVID-19 vaccines in preventing infection:
# --------------------------------------
# I do not know                                                                                                         147
# Is still in doubt and will only be known once the COVID-19 vaccines that have been approved are used for some time    143
# Is quite high in vaccines that have been approved                                                                     123
# Name: The effectiveness of COVID-19 vaccines in preventing infection:, dtype: int64
# --------------------------------------
#
# --------------------------------------
# People who have already suffered COVID-19 infection:
# --------------------------------------
# Should get the COVID-19 vaccine        288
# I do not know                           80
# Should not get the COVID-19 vaccine     45
# Name: People who have already suffered COVID-19 infection:, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ1: Attitude on Contextual Influences
# --------------------------------------
# Radio/TV                  229
# Social media               46
# 1,2                        40
# 2,4                        19
# IEC materials from MoH     17
# Community meetings         14
# 2,3,4                       6
# Other (Explain)             5
# 1,2,4                       5
# 1,4                         4
# 2,3                         3
# 2,1                         3
# 1TTITU45 3ONT5XU1L          3
# 2,5                         2
# 2,4,5                       2
# 1,2,3,4                     2
# 1 ,2                        2
# N/1                         2
# 4,5                         1
# 3,4                         1
# 1.3                         1
# 1,3                         1
# 1,5                         1
# 1,2,3                       1
# 2 ,4                        1
# 2 ,5                        1
# 1,2,4,5                     1
# Name: ACQ1: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ2: Attitude on Contextual Influences
# --------------------------------------
# Fellow health workers                   316
# Other (Explain)                          37
# Internet                                 24
# Friends/relatives                        10
# 2,3                                       6
# 3,4                                       4
# 1,3                                       3
# N/1                                       3
# 4 N/1                                     2
# 3HEW                                      2
# 4 he1lth worker from the motoury          1
# 4 he1lth f13ulty he1lth 31re worker1      1
# my 3HEW or He1lth f13ility (ne1rer)       1
# 1,2,3                                     1
# N1                                        1
# 1,2                                       1
# Name: ACQ2: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ3: Attitude on Contextual Influences
# --------------------------------------
# No     389
# Yes     24
# Name: ACQ3: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ4: Attitude on Contextual Influences
# --------------------------------------
# No     277
# Yes    136
# Name: ACQ4: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ5: Attitude on Contextual Influences
# --------------------------------------
# No     346
# Yes     67
# Name: ACQ5: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ6: Attitude on Contextual Influences
# --------------------------------------
# Yes    370
# No      43
# Name: ACQ6: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# ACQ7: Attitude on Contextual Influences
# --------------------------------------
# Yes    369
# No      44
# Name: ACQ7: Attitude on Contextual Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ1: Attitude on Individual and Group Influences
# --------------------------------------
# No     370
# Yes     43
# Name: AIQ1: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ12: Attitude on Individual and Group Influences
# --------------------------------------
# No     284
# Yes    129
# Name: AIQ12: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ3: Attitude on Individual and Group Influences
# --------------------------------------
# Yes    325
# No      88
# Name: AIQ3: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ4: Attitude on Individual and Group Influences
# --------------------------------------
# Yes    369
# No      44
# Name: AIQ4: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ5: Attitude on Individual and Group Influences
# --------------------------------------
# Yes    342
# No      71
# Name: AIQ5: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AIQ6: Attitude on Individual and Group Influences
# --------------------------------------
# Yes    340
# No      73
# Name: AIQ6: Attitude on Individual and Group Influences, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ1: Attitude on Vaccine safety and vaccination specific issues
# --------------------------------------
# Yes    278
# No     135
# Name: AVSQ1: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ2: Attitudeon  Vaccine safety and vaccination specific issues
# --------------------------------------
# Yes    370
# No      43
# Name: AVSQ2: Attitudeon  Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ3: Attitude on Vaccine safety and vaccination specific issues
# --------------------------------------
# Confident               133
# Somehow confident       131
# Very confident           82
# Don't know               27
# Not confident            21
# Not confident at all     19
# Name: AVSQ3: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ4: Attitude on Vaccine safety and vaccination specific issues
# --------------------------------------
# Somewhat        141
# Not at all      102
# Not too much     78
# Don't know       50
# Very much        42
# Name: AVSQ4: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ5: Attitude on Vaccine safety and vaccination specific issues
# --------------------------------------
# I don’t have any concerns about the COVID-19 vaccine                                                                      182
# The government might not be able to ensure enough supply of the vaccine and therefore result in a more negative effect     60
# Vaccines are not tested enough for safety                                                                                  28
# The ingredients used to make the COVID-19 vaccine are unsafe                                                               17
# The COVID-19 vaccine might be very expensive for many people to afford                                                     14
# 1,7,8                                                                                                                      14
# The vaccine might cause chronic diseases                                                                                   12
# 7,8                                                                                                                        11
# 1,2                                                                                                                        10
# People cannot be vaccinated for a disease they do not have                                                                  8
# The COVID-19 vaccine might weaken the immunity of the people                                                                8
# Vaccine is only given to people who are seriously infected with the virus                                                   5
# 1,3                                                                                                                         5
# 1,8                                                                                                                         5
# 1,6                                                                                                                         4
# 5,6,8                                                                                                                       3
# 1,2,3                                                                                                                       2
# 1,9                                                                                                                         2
# 2,8                                                                                                                         2
# 1,5,6                                                                                                                       2
# 1,2,6                                                                                                                       2
# 1,8,9                                                                                                                       2
# 3,6                                                                                                                         2
# 3,8                                                                                                                         1
# 1,2,3,8                                                                                                                     1
# 1,3,8                                                                                                                       1
# 6,7                                                                                                                         1
# 1,6,7                                                                                                                       1
# 2,3                                                                                                                         1
# 3,7,8                                                                                                                       1
# 1,2,5                                                                                                                       1
# 1,2,8                                                                                                                       1
# 2,6                                                                                                                         1
# 1,4,5                                                                                                                       1
# 1,7                                                                                                                         1
# 6,8                                                                                                                         1
# Name: AVSQ5: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# AVSQ6: Attitude on Vaccine safety and vaccination specific issues
# --------------------------------------
# Somewhat        176
# Very much       101
# Don't know       65
# Not too much     58
# Not at all       13
# Name: AVSQ6: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Source
# --------------------------------------
# Radio/TV                                        232
# Social media                                     48
# Social media/Radio/TV                            46
# Radio/TV/IEC/Community meeting                   29
# Social media/Radio/TV/IEC/Community meetings     24
# IEC materials                                    18
# Community meetings                               16
# Name: Source, dtype: int64
# --------------------------------------
#
# --------------------------------------
# Information
# --------------------------------------
# Fellow health workers    328
# Other                     39
# Internet                  30
# Friends/relatives         16
# Name: Information, dtype: int64
# --------------------------------------

# %%
columns = data[data.columns]

for col in columns:
    unique = data[col].unique()
    # print(col[:5],':',len(unique),unique) #print all unique values

    # print for those with too many unique values
    if len(unique) > 11:
        print(col[:5], ':', len(unique), 'values', '->', unique, '\n')
# Out:
# ACQ1: : 27 values -> ['Radio/TV' 'IEC materials from MoH' '1,2' 'Community meetings'
#  'Social media' 'Other (Explain)' '1,2,3,4' '2 ,5' '2,4' '2,5' '1,2,4'
#  '2,1' '1,4' '1,5' '2,3,4' '2,4,5' '2 ,4' '2,3' '1 ,2' '1,2,3' 'N/1'
#  '1TTITU45 3ONT5XU1L' '4,5' '1,3' '1.3' '3,4' '1,2,4,5']
#
# ACQ2: : 16 values -> ['Internet' 'Fellow health workers' '4 he1lth worker from the motoury'
#  'Friends/relatives' '1,3' 'Other (Explain)'
#  '4 he1lth f13ulty he1lth 31re worker1' '4 N/1' '3,4' '2,3' 'N/1' '3HEW'
#  'my 3HEW or He1lth f13ility (ne1rer)' '1,2,3' 'N1' '1,2']
#
# AVSQ5 : 36 values -> ['The government might not be able to ensure enough supply of the vaccine and therefore result in a more negative effect'
#  '1,8' '1,4,5' 'Vaccines are not tested enough for safety'
#  'The COVID-19 vaccine might weaken the immunity of the people'
#  'Vaccine is only given to people who are seriously infected with the virus'
#  'I don’t have any concerns about the COVID-19 vaccine'
#  'People cannot be vaccinated for a disease they do not have' '3,6'
#  'The ingredients used to make the COVID-19 vaccine are unsafe'
#  'The vaccine might cause chronic diseases' '1,2' '1,7,8' '7,8' '1,2,5'
#  '3,7,8'
#  'The COVID-19 vaccine might be very expensive for many people to afford'
#  '6,7' '6,8' '1,8,9' '3,8' '1,2,3' '5,6,8' '1,2,3,8' '1,3,8' '1,5,6'
#  '1,6,7' '2,3' '1,3' '1,9' '1,2,8' '1,6' '2,6' '2,8' '1,7' '1,2,6']

# %%
# Columns ACQ1, ACQ2 & AVSQ5 have messy values, and based on the document,
# Source, Information, ACQ1 & ACQ2 don't hold useful data, and info in AVSQ5 is also represented in AVSQ6.
# so deleting these columns to make preprocessing easier

new_data = data.drop(labels=[
    'ACQ1: Attitude on Contextual Influences',
    'ACQ2: Attitude on Contextual Influences',
    'AVSQ5: Attitude on Vaccine safety and vaccination specific issues',
    'Source',
    'Information'
], axis=1)

# new_data.columns.to_list()

# %% [markdown]
# Encoding Data

# %%
# copied from https://stackoverflow.com/a/58239419
class MultiColumnLabelEncoder:

    def __init__(self, columns=None):
        self.columns = columns  # array of column names to encode

    def fit(self, X, y=None):
        self.encoders = {}
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            self.encoders[col] = LabelEncoder().fit(X[col])
        return self

    def transform(self, X):
        output = X.copy()
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            output[col] = self.encoders[col].transform(X[col])
        return output

    def fit_transform(self, X, y=None):
        return self.fit(X, y).transform(X)

    def inverse_transform(self, X):
        output = X.copy()
        columns = X.columns if self.columns is None else self.columns
        for col in columns:
            output[col] = self.encoders[col].inverse_transform(X[col])
        return output

# %%
multi_encoder = MultiColumnLabelEncoder(new_data.columns.to_list())
encoded_dataset = multi_encoder.fit_transform(new_data)

# %% [markdown]
# verify encoding columns used to create label

# %%
# encoded_dataset
a = encoded_dataset["ACQ6: Attitude on Contextual Influences"]
b = encoded_dataset["ACQ7: Attitude on Contextual Influences"]
c = encoded_dataset["AIQ1: Attitude on Individual and Group Influences"]
d = encoded_dataset["AIQ4: Attitude on Individual and Group Influences"]
e = encoded_dataset["AIQ5: Attitude on Individual and Group Influences"]
f = encoded_dataset["AVSQ1: Attitude on Vaccine safety and vaccination specific issues"]
g = encoded_dataset["AVSQ6: Attitude on Vaccine safety and vaccination specific issues"]

p = [a, b, c, d, e, f, g]
for i in p:
    print(i.value_counts())
# Out:
# 1    370
# 0     43
# Name: ACQ6: Attitude on Contextual Influences, dtype: int64
# 1    369
# 0     44
# Name: ACQ7: Attitude on Contextual Influences, dtype: int64
# 0    370
# 1     43
# Name: AIQ1: Attitude on Individual and Group Influences, dtype: int64
# 1    369
# 0     44
# Name: AIQ4: Attitude on Individual and Group Influences, dtype: int64
# 1    342
# 0     71
# Name: AIQ5: Attitude on Individual and Group Influences, dtype: int64
# 1    278
# 0    135
# Name: AVSQ1: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# 3    176
# 4    101
# 0     65
# 2     58
# 1     13
# Name: AVSQ6: Attitude on Vaccine safety and vaccination specific issues, dtype: int64

# %%
inv = multi_encoder.inverse_transform(encoded_dataset)

s = inv["ACQ6: Attitude on Contextual Influences"]
t = inv["ACQ7: Attitude on Contextual Influences"]
u = inv["AIQ1: Attitude on Individual and Group Influences"]
v = inv["AIQ4: Attitude on Individual and Group Influences"]
w = inv["AIQ5: Attitude on Individual and Group Influences"]
x = inv["AVSQ1: Attitude on Vaccine safety and vaccination specific issues"]
j = inv["AVSQ6: Attitude on Vaccine safety and vaccination specific issues"]

q = [s, t, u, v, w, x, j]
for i in q:
    print(i.value_counts())
# Out:
# Yes    370
# No      43
# Name: ACQ6: Attitude on Contextual Influences, dtype: int64
# Yes    369
# No      44
# Name: ACQ7: Attitude on Contextual Influences, dtype: int64
# No     370
# Yes     43
# Name: AIQ1: Attitude on Individual and Group Influences, dtype: int64
# Yes    369
# No      44
# Name: AIQ4: Attitude on Individual and Group Influences, dtype: int64
# Yes    342
# No      71
# Name: AIQ5: Attitude on Individual and Group Influences, dtype: int64
# Yes    278
# No     135
# Name: AVSQ1: Attitude on Vaccine safety and vaccination specific issues, dtype: int64
# Somewhat        176
# Very much       101
# Don't know       65
# Not too much     58
# Not at all       13
# Name: AVSQ6: Attitude on Vaccine safety and vaccination specific issues, dtype: int64

# %% [markdown]
# Create Labels

# %%
# CREATE LABEL BASED ON INFORMATION IN PAPER. these columns can affect hesitancy most
# ac 6 - In your view is the MoH making the right decisions on COVID-19 vaccination?
# positive = 1, negative = 0
# ac 7 - Do you think vaccine manufacturers have good intentions for you and people in your community
# positive = 1, negative = 0
# ai 1 - Are you aware of any bad reactions in people who have had COVID-19 vaccination?
# positive = 0, negative = 1
# ai 4 - Do you trust what the MoH says about COVID-19 vaccination
# positive = 1, negative = 0
# ai 5 - In your view is the COVID-19 vaccine safe enough for people to be injected
# positive = 1, negative = 0
# av 1 - Do you feel our country can manage risks associated with COVID-19 vaccine side effects?
# positive = 1, negative = 0
# av 6 - In general, how safe do you think COVID-19 vaccine is for the general population
# values 0-4, positive=3,4, negative=1,2, neutral=0

a = encoded_dataset["ACQ6: Attitude on Contextual Influences"]
b = encoded_dataset["ACQ7: Attitude on Contextual Influences"]
c = encoded_dataset["AIQ1: Attitude on Individual and Group Influences"]
d = encoded_dataset["AIQ4: Attitude on Individual and Group Influences"]
e = encoded_dataset["AIQ5: Attitude on Individual and Group Influences"]
f = encoded_dataset["AVSQ1: Attitude on Vaccine safety and vaccination specific issues"]
g = encoded_dataset["AVSQ6: Attitude on Vaccine safety and vaccination specific issues"]

# logic behind this formula: higher result value means more positive values in the row (based on the encodings), meaning less hesitancy
res = (a+b-c+d+e+f+g)/7
print(res.value_counts())

tmp = []
for i in res:
    if i < 0.7:
        tmp.append(1)  # 1 means hesitant
    else:
        tmp.append(0)  # 0 means not hesitant

df_label = pd.DataFrame(tmp)

new_data["Label"] = df_label  # add the labels to new_data dataframe

df_label.value_counts()  # this should show 3339 0s & 74 1s, i.e. 82% of users are not hesitant, almost in line with the paper which have 81%
# Out:
# 1.142857    129
# 1.285714     69
# 1.000000     65
# 0.714286     38
# 0.857143     38
# 0.571429     30
# 0.428571     24
# 0.285714     12
# 0.142857      4
# 0.000000      4
# dtype: int64
# 0    339
# 1     74
# dtype: int64

# %% [markdown]
# Correlation among data

# %%
data_corr = encoded_dataset.corr()
data_corr
# Out:
#                                                       County  District  \
# County                                              1.000000  0.434480
# District                                            0.434480  1.000000
# Sex                                                -0.032420  0.119739
# Age                                                 0.214880 -0.127390
# Religion                                            0.037971  0.038661
# Education                                           0.211119  0.011283
# Years                                              -0.032215 -0.002427
# Households                                          0.401359  0.259373
# Have you had MoH approved training on COVID-19?     0.055250  0.201972
# Have you been involved in educating the communi... -0.121311  0.007150
# Your main source of Income                          0.000191 -0.268780
# Have you attended a course where COVID-19 vacci...  0.085401  0.079686
# Do you have access to COVID-19 vaccination mate... -0.063384  0.097788
# Do you have a designated person with knowledge ... -0.192213 -0.163796
# Concerning how the COVID-19 vaccines work to pr...  0.114744 -0.016852
# To what extent do you think you are well-inform...  0.106342 -0.013087
# Do you know what the COVID-19 vaccine contains?     0.102136  0.055781
# What should the people who have received the CO...  0.133600  0.125789
# The effectiveness of COVID-19 vaccines in preve...  0.151790  0.117307
# People who have already suffered COVID-19 infec...  0.031621  0.050494
# ACQ3: Attitude on Contextual Influences             0.038606  0.015501
# ACQ4: Attitude on Contextual Influences            -0.049223  0.017089
# ACQ5: Attitude on Contextual Influences             0.076999  0.184512
# ACQ6: Attitude on Contextual Influences             0.079063 -0.055910
# ACQ7: Attitude on Contextual Influences             0.049140  0.086382
# AIQ1: Attitude on Individual and Group Influences   0.179099  0.006723
# AIQ12: Attitude on Individual and Group Influences -0.138707 -0.181192
# AIQ3: Attitude on Individual and Group Influences   0.140446  0.014608
# AIQ4: Attitude on Individual and Group Influences   0.119639  0.027953
# AIQ5: Attitude on Individual and Group Influences   0.103325  0.036431
# AIQ6: Attitude on Individual and Group Influences   0.133487  0.001440
# AVSQ1: Attitude on Vaccine safety and vaccinati...  0.161212 -0.017467
# AVSQ2: Attitudeon  Vaccine safety and vaccinati...  0.150280  0.027708
# AVSQ3: Attitude on Vaccine safety and vaccinati... -0.039594  0.148715
# AVSQ4: Attitude on Vaccine safety and vaccinati...  0.031365 -0.033355
# AVSQ6: Attitude on Vaccine safety and vaccinati...  0.141524 -0.057850
#
#                                                          Sex       Age  \
# County                                             -0.032420  0.214880
# District                                            0.119739 -0.127390
# Sex                                                 1.000000 -0.114628
# Age                                                -0.114628  1.000000
# Religion                                            0.058007 -0.016506
# Education                                           0.038379  0.180700
# Years                                              -0.000569 -0.150818
# Households                                         -0.102204  0.131754
# Have you had MoH approved training on COVID-19?    -0.004876 -0.053750
# Have you been involved in educating the communi... -0.014776 -0.028655
# Your main source of Income                         -0.022714  0.148197
# Have you attended a course where COVID-19 vacci... -0.028279  0.043469
# Do you have access to COVID-19 vaccination mate...  0.050311 -0.067973
# Do you have a designated person with knowledge ... -0.032225 -0.072594
# Concerning how the COVID-19 vaccines work to pr... -0.020840  0.035649
# To what extent do you think you are well-inform... -0.150174  0.084902
# Do you know what the COVID-19 vaccine contains?     0.030866 -0.040732
# What should the people who have received the CO... -0.010975  0.041584
# The effectiveness of COVID-19 vaccines in preve...  0.142025  0.015056
# People who have already suffered COVID-19 infec... -0.096281 -0.043105
# AVSQ1: Attitude on Vaccine safety and vaccinati...                                         0.136820
# AVSQ2: Attitudeon  Vaccine safety and vaccinati...                                         0.085581
# AVSQ3: Attitude on Vaccine safety and vaccinati...                                         0.064592
# AVSQ4: Attitude on Vaccine safety and vaccinati...                                         0.070652
# AVSQ6: Attitude on Vaccine safety and vaccinati...                                         0.056968
#
#                                                     Have you been involved in educating the community on COVID-19?  \
# County                                                                                      -0.121311
# District                                                                                     0.007150
# Sex                                                                                         -0.014776
# Age                                                                                         -0.028655
# Religion                                                                                    -0.067252
# Education                                                                                   -0.024172
# Years                                                                                       -0.022104
# Households                                                                                   0.073478
# Have you had MoH approved training on COVID-19?                                              0.573360
# Have you been involved in educating the communi...                                           1.000000
# Your main source of Income                                                                   0.054830
# Have you attended a course where COVID-19 vacci...                                           0.111989
# Do you have access to COVID-19 vaccination mate...                                           0.105828
# Do you have a designated person with knowledge ...                                           0.249820
# Concerning how the COVID-19 vaccines work to pr...                                           0.141792
# To what extent do you think you are well-inform...                                           0.022190
# Do you know what the COVID-19 vaccine contains?                                              0.105465
# What should the people who have received the CO...                                           0.051775
# The effectiveness of COVID-19 vaccines in preve...                                           0.104289
# People who have already suffered COVID-19 infec...                                           0.002189
# ACQ3: Attitude on Contextual Influences                                                      0.069384
# ACQ4: Attitude on Contextual Influences                                                      0.086189
# ACQ5: Attitude on Contextual Influences                                                      0.042787
# ACQ6: Attitude on Contextual Influences                                                      0.047474
# ACQ7: Attitude on Contextual Influences                                                     -0.024406
# AIQ1: Attitude on Individual and Group Influences                                           -0.070459
# AIQ12: Attitude on Individual and Group Influences                                           0.057618
# AIQ3: Attitude on Individual and Group Influences                                            0.031797
# AIQ4: Attitude on Individual and Group Influences                                            0.043854
# AIQ5: Attitude on Individual and Group Influences                                            0.171190
# AIQ6: Attitude on Individual and Group Influences                                            0.127439
# AVSQ1: Attitude on Vaccine safety and vaccinati...                                           0.080337
# AVSQ2: Attitudeon  Vaccine safety and vaccinati...                                           0.024488
# AVSQ3: Attitude on Vaccine safety and vaccinati...                                           0.035546
# AVSQ4: Attitude on Vaccine safety and vaccinati...                                           0.157003
# AVSQ6: Attitude on Vaccine safety and vaccinati...                                           0.050180
#
#                                                     ...  \
# County                                              ...
# District                                            ...
# Sex                                                 ...
# Age                                                 ...
# Religion                                            ...
# Education                                           ...
# Years                                               ...
# Households                                          ...
# Have you had MoH approved training on COVID-19?     ...
# Have you been involved in educating the communi...  ...
# Your main source of Income                          ...
# Have you attended a course where COVID-19 vacci...  ...
# Do you have access to COVID-19 vaccination mate...  ...
# Do you have a designated person with knowledge ...  ...
# Concerning how the COVID-19 vaccines work to pr...  ...
# To what extent do you think you are well-inform...  ...
# Do you know what the COVID-19 vaccine contains?     ...
# What should the people who have received the CO...  ...
# The effectiveness of COVID-19 vaccines in preve...  ...
# People who have already suffered COVID-19 infec...  ...
# ACQ3: Attitude on Contextual Influences             ...
# ACQ4: Attitude on Contextual Influences             ...
# ACQ5: Attitude on Contextual Influences             ...
# ACQ6: Attitude on Contextual Influences             ...
# ACQ7: Attitude on Contextual Influences             ...
# AIQ1: Attitude on Individual and Group Influences   ...
# AIQ12: Attitude on Individual and Group Influences  ...
# AIQ3: Attitude on Individual and Group Influences   ...
# AIQ4: Attitude on Individual and Group Influences   ...
# AIQ5: Attitude on Individual and Group Influences   ...
# AIQ6: Attitude on Individual and Group Influences   ...
# AVSQ1: Attitude on Vaccine safety and vaccinati...  ...
# AVSQ2: Attitudeon  Vaccine safety and vaccinati
# Do you know what the COVID-19 vaccine contains?                                              0.059337
# What should the people who have received the CO...                                           0.143847
# The effectiveness of COVID-19 vaccines in preve...                                           0.199865
# People who have already suffered COVID-19 infec...                                           0.208981
# ACQ3: Attitude on Contextual Influences                                                      0.057593
# ACQ4: Attitude on Contextual Influences                                                     -0.017119
# ACQ5: Attitude on Contextual Influences                                                     -0.154895
# ACQ6: Attitude on Contextual Influences                                                      0.159001
# ACQ7: Attitude on Contextual Influences                                                      0.154834
# AIQ1: Attitude on Individual and Group Influences                                            0.051260
# AIQ12: Attitude on Individual and Group Influences                                           0.014244
# AIQ3: Attitude on Individual and Group Influences                                            0.255723
# AIQ4: Attitude on Individual and Group Influences                                            0.232142
# AIQ5: Attitude on Individual and Group Influences                                            0.347199
# AIQ6: Attitude on Individual and Group Influences                                            0.199786
# AVSQ1: Attitude on Vaccine safety and vaccinati...                                           0.363043
# AVSQ2: Attitudeon  Vaccine safety and vaccinati...                                           0.231090
# AVSQ3: Attitude on Vaccine safety and vaccinati...                                           0.039571
# AVSQ4: Attitude on Vaccine safety and vaccinati...                                           0.176542
# AVSQ6: Attitude on Vaccine safety and vaccinati...                                           1.000000
#
# [36 rows x 36 columns]

# %%
# plot correlation
mask1 = np.triu(np.ones_like(data_corr, dtype=bool))
mask2 = np.tril(np.ones_like(data_corr, dtype=bool))
plt.figure(figsize=(30, 30))
sns.heatmap(data_corr, annot=True, cmap="seismic", mask=mask1)
# Out:
# <AxesSubplot:>

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is highly correlated with another feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of the redundant columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr


# remove columns that are highly correlated
corr_features = correlation(data_corr, 0.6)
print(len(corr_features))
print(corr_features)


# drop higly correlated columns
for i in corr_features:
    new_data.drop(i, axis=1, inplace=True)
    #encoded_dataset.drop(i,axis=1, inplace=True)
# Out:
# 8
# {'AIQ5: Attitude on Individual and Group Influences', 'AIQ6: Attitude on Individual and Group Influences', 'AVSQ1: Attitude on Vaccine safety and vaccination specific issues', 'AIQ4: Attitude on Individual and Group Influences', 'AVSQ6: Attitude on Vaccine safety and vaccination specific issues', 'Households', 'Have you been involved in educating the community on COVID-19?', 'AVSQ2: Attitudeon  Vaccine safety and vaccination specific issues'}

# %% [markdown]
# Train-Test Split

# %%
# TRAIN TEST SPLIT

df = new_data

# https://pandas.pydata.org/pandas-docs/stable/getting_started/comparison/comparison_with_sql.html#where
df1 = df[df['County'] == 'Nairobi']
df2 = df[df['County'] == 'Mombasa']
df3 = df[df['County'] == 'Trans Nzoia']
df4 = df[df['County'] == 'Kajiado']

# take samples from each county for train set and leave rest for test
df1_train, df1_test = train_test_split(df1, train_size=0.6)
df2_train, df2_test = train_test_split(df2, train_size=0.6)
df3_train, df3_test = train_test_split(df3, train_size=0.6)
df4_train, df4_test = train_test_split(df4, train_size=0.6)

# joining splitted county datas to test and train sets
df_train = pd.concat([df1_train, df2_train, df3_train,
                     df4_train], ignore_index=True)
df_test = pd.concat([df1_test, df2_test, df3_test,
                    df4_test], ignore_index=True)
# print(df_train.columns.to_list())
print(df_train.shape)
print(df_test.shape)

# train labels
df_train_label = df_train.Label
df_train = df_train.drop('Label', axis=1)
print("columns used for training:", df_train.columns.to_list())

# test labels
df_test_label = df_test.Label
df_test = df_test.drop('Label', axis=1)

# encode for building model
for i in corr_features:
    # removing removed coorelated columns from encoder or it give error
    multi_encoder.columns.remove(i)

df_train_enc = multi_encoder.fit_transform(df_train)
df_test_enc = multi_encoder.fit_transform(df_test)

print(df_train_label.value_counts())
print(df_test_label.value_counts())
# Out:
# (246, 29)
# (167, 29)
# columns used for training: ['County', 'District', 'Sex', 'Age', 'Religion', 'Education', 'Years', 'Have you had MoH approved training on COVID-19?', 'Your main source of Income', 'Have you attended a course where COVID-19 vaccination was discussed?', 'Do you have access to COVID-19 vaccination materials (literature, IEC materials) for quick reference when necessary?', 'Do you have a designated person with knowledge on COVID-19 vaccination whom you can consult when you have a question on COVID-19 vaccination?', 'Concerning how the COVID-19 vaccines work to prevent infection', 'To what extent do you think you are well-informed enough about COVID-19 vaccine to sensitize your family/ community members?', 'Do you know what the COVID-19 vaccine contains?', 'What should the people who have received the COVID-19 vaccine do?', 'The effectiveness of COVID-19 vaccines in preventing infection:', 'People who have already suffered COVID-19 infection:', 'ACQ3: Attitude on Contextual Influences', 'ACQ4: Attitude on Contextual Influences', 'ACQ5: Attitude on Contextual Influences', 'ACQ6: Attitude on Contextual Influences', 'ACQ7: Attitude on Contextual Influences', 'AIQ1: Attitude on Individual and Group Influences', 'AIQ12: Attitude on Individual and Group Influences', 'AIQ3: Attitude on Individual and Group Influences', 'AVSQ3: Attitude on Vaccine safety and vaccination specific issues', 'AVSQ4: Attitude on Vaccine safety and vaccination specific issues']
# 0    206
# 1     40
# Name: Label, dtype: int64
# 0    133
# 1     34
# Name: Label, dtype: int64

# %% [markdown]
# Building Model

# %%
# build svm classifier model

svmc = svm.LinearSVC(max_iter=6000) #set max_iter to get rid of cannot converge error

svmc.fit(df_train_enc, df_train_label)

y_pred_svm = svmc.predict(df_train_enc)
y_testpred_svm = svmc.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred_svm))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred_svm))
# Out:
# Training Accuracy: 0.8902439024390244
# Test Accuracy: 0.8263473053892215

# %%
# build logistic regression model

logistic_regression = LogisticRegression()

logistic_regression.fit(df_train_enc, df_train_label)

y_pred_lr = logistic_regression.predict(df_train_enc)
y_testpred_lr = logistic_regression.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred_lr))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred_lr))
# Out:
# Training Accuracy: 0.8739837398373984
# Test Accuracy: 0.8263473053892215

# %%
# test different depths for decision tree

maxdepths = [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for i in maxdepths:
    decision_tree_classifier = DecisionTreeClassifier(max_depth=i)

    decision_tree_classifier = decision_tree_classifier.fit(
        df_train_enc, df_train_label)

    y_pred2 = decision_tree_classifier.predict(df_train_enc)
    y_testpred2 = decision_tree_classifier.predict(df_test_enc)

    trainAcc[index] = accuracy_score(df_train_label, y_pred2)
    testAcc[index] = accuracy_score(df_test_label, y_testpred2)

    if accuracy_score(df_train_label, y_pred2) < 1:
        print("Training Accuracy:", accuracy_score(df_train_label, y_pred2))
        print("Test Accuracy:", accuracy_score(df_test_label, y_testpred2))
        print("depth:", i, "\n")

    index += 1

# plot accuracy at different depth
plt.figure(figsize=(10, 5))
plt.plot(maxdepths, trainAcc, 'ro-', maxdepths, testAcc, 'bv--')
plt.legend(['Training Accuracy', 'Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy')
# Out:
# Training Accuracy: 0.8658536585365854
# Test Accuracy: 0.7844311377245509
# depth: 2
#
# Training Accuracy: 0.9065040650406504
# Test Accuracy: 0.8263473053892215
# depth: 3
#
# Training Accuracy: 0.9227642276422764
# Test Accuracy: 0.8323353293413174
# depth: 4
#
# Training Accuracy: 0.9552845528455285
# Test Accuracy: 0.8143712574850299
# depth: 5
#
# Training Accuracy: 0.9634146341463414
# Test Accuracy: 0.8203592814371258
# depth: 6
#
# Training Accuracy: 0.9878048780487805
# Test Accuracy: 0.8023952095808383
# depth: 7
# Text(0, 0.5, 'Accuracy')

# %%
# build decision tree model

decision_tree_classifier = DecisionTreeClassifier(max_depth=5)  # after max depth 4, it starts overfitting

decision_tree_classifier = decision_tree_classifier.fit(df_train_enc, df_train_label)

y_pred = decision_tree_classifier.predict(df_train_enc)
y_testpred = decision_tree_classifier.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred))
# Out:
# Training Accuracy: 0.9552845528455285
# Test Accuracy: 0.8203592814371258

# %%
# build random forest model

rf = RandomForestClassifier(max_depth=5)

rf.fit(df_train_enc, df_train_label)

y_pred_rf = rf.predict(df_train_enc)
y_testpred_rf = rf.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred_rf))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred_rf))
# Out:
# Training Accuracy: 0.9308943089430894
# Test Accuracy: 0.8562874251497006

# %%
# xgboost

xgb_classifier = xgb.XGBClassifier(max_depth=5)

xgb_classifier.fit(df_train_enc, df_train_label)

y_pred_xgb = xgb_classifier.predict(df_train_enc)
y_testpred_xgb = xgb_classifier.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred_xgb))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred_xgb))
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 0.8622754491017964

# %%
# save best model for deployment
# best model from testing: XGBClassifier

file_name = "xgb_classifier.pkl"

# to save fitted model
pickle.dump(xgb_classifier, open(file_name, "wb"))

# to load model again
xgb_model_loaded : xgb.XGBClassifier = pickle.load(open(file_name, "rb"))


#test loaded model

y_pred_xgb_load = xgb_model_loaded.predict(df_train_enc)
y_testpred_xgb_load = xgb_model_loaded.predict(df_test_enc)

print("Training Accuracy:", accuracy_score(df_train_label, y_pred_xgb_load))
print("Test Accuracy:", accuracy_score(df_test_label, y_testpred_xgb_load))
# Out:
# Training Accuracy: 1.0
# Test Accuracy: 0.8622754491017964
